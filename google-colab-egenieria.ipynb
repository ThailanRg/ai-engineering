# %% [markdown]
# <a href="https://colab.research.google.com/github/ThailanRg/ai-engineering/blob/main/google-colab-egenieria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Integrando com API Gemini

# %%
import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get('GEMINI_API_KEY')

# %%
from google import genai
client = genai.Client()

# %%
chat = client.chats.create(model = "gemini-2.5-flash")

# %%
promp = input("Digite uma pergunta: ")

while promp != "fim":
  try:
    resposta = chat.send_message(promp)
    print(resposta.text)
  except Exception as e:
    print("Limite atingido, aguardando...")
  promp = input("Digite uma pergunta: ")
# Out:
# Digite uma pergunta: O QUE E FAMILIA
# A família é um conceito **multifacetado e fundamental** que se refere a um grupo de indivíduos geralmente unidos por laços de parentesco (consanguinidade, casamento, adoção) ou por laços afetivos e de convivência. É a primeira e mais importante instituição social na vida da maioria das pessoas.
#
# Embora a definição possa variar culturalmente e ao longo do tempo, a essência da família está na **construção de relações de afeto, cuidado, apoio e solidariedade**.
#
# Vamos explorar os principais aspectos:
#
# 1.  **A Definição Tradicional/Biológica:**
#     *   Tradicionalmente, a família era vista como um núcleo composto por pai, mãe e filhos, geralmente vivendo sob o mesmo teto e unidos por parentesco biológico ou legal (casamento/adoção).
#
# 2.  **A Evolução e Expansão do Conceito (Família Moderna):**
#     *   Hoje, reconhece-se que a família vai muito além da consanguinidade e das estruturas tradicionais. O que define a família não é apenas o parentesco legal ou biológico, mas a **construção de laços de afeto, cuidado, apoio e solidariedade**.
#     *   **Tipos de famílias que se encaixam nesta visão ampla:**
#         *   **Famílias nucleares:** Pai, mãe e filhos.
#         *   **Famílias monoparentais:** Um dos pais com seus filhos.
#         *   **Famílias estendidas:** Incluem avós, tios, primos, etc., vivendo próximos ou sob o mesmo teto.
#         *   **Famílias recompostas/mistas:** Formadas por cônjuges que já tinham filhos de relacionamentos anteriores.
#         *   **Famílias homoafetivas:** Casais do mesmo sexo com ou sem filhos (biológicos, adotados, de reprodução assistida).
#         *   **Famílias por adoção:** Crianças adotadas legalmente, criando laços de parentesco com seus pais adotivos.
#         *   **Famílias de acolhimento:** Indivíduos ou casais que acolhem temporariamente crianças ou jovens em situação de vulnerabilidade.
#         *   **"Famílias de escolha" (ou famílias afetivas):** Grupos de amigos ou indivíduos que, mesmo sem laços sanguíneos ou legais, funcionam como uma família, oferecendo apoio mútuo, amor e pertencimento.
#
# 3.  **Elementos Essenciais da Família (Independente da Forma):**
#     *   **Afeto e Amor:** Uma base fundamental de carinho, compaixão e união.
#     *   **Apoio e Proteção:** Ser um porto seguro, um refúgio onde se encontra ajuda e segurança em momentos de necessidade.
#     *   **Convivência e Compartilhamento:** Compartilhar experiências, rotinas, alegrias e tristezas.
#     *   **Identidade e Pertencimento:** Sentimento de fazer parte de algo maior, de ter um lugar no mundo. A família ajuda a moldar quem somos.
#     *   **Cuidado e Responsabilidade Mútua:** Preocupar-se com o bem-estar dos outros membros e assumir responsabilidades.
#
# 4.  **Funções da Família:**
#     *   **Socialização:** Ensinar valores, normas sociais, costumes e habilidades para a vida em sociedade.
#     *   **Desenvolvimento Emocional:** Proporcionar segurança emocional, autoestima e um ambiente para o desenvolvimento afetivo.
#     *   **Apoio Material:** Oferecer moradia, alimentação, vestuário e outras necessidades básicas.
#     *   **Transmissão Cultural:** Preservar e transmitir tradições, história e legados culturais.
#     *   **Suporte em Crises:** Ser uma rede de apoio para lidar com desafios, perdas e momentos difíceis.
#
# Em resumo, a família é muito mais do que um conjunto de pessoas ligadas por sangue ou casamento. É um espaço de construção de identidades, de compartilhamento de vidas, de aprendizado e de refúgio emocional. É onde muitos encontram seu primeiro e mais significativo senso de pertencimento e onde se aprende a dar e receber amor. A forma pode variar imensamente, mas a essência de um grupo que se importa e se apoia permanece como seu cerne.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17023/1936584592.py in <cell line: 0>()
#       7   except Exception as e:
#       8     print("Limite atingido, aguardando...")
# ----> 9   promp = input("Digite uma pergunta: ")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Estruturas de repetição

# %%
n = 1
while n <= 2:
   print("*")
   n = n + 1
# Out:
# *
# *

# %% [markdown]
# # Lista
