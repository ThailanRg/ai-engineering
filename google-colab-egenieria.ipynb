# %% [markdown]
# <a href="https://colab.research.google.com/github/ThailanRg/ai-engineering/blob/main/google-colab-egenieria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Integrando com API Gemini

# %%
import os
from google.colab import userdata
from google import genai

os.environ["GOOGLE_API_KEY"] = userdata.get('GEMINI_API_KEY')
client = genai.Client()
chat = client.chats.create(model = "gemini-2.5-flash")
promp = input("Digite uma pergunta: ")

while promp != "fim":
  try:
    resposta = chat.send_message(promp)
    print(resposta.text)
  except Exception as e:
    print("Limite atingido, aguardando...")
  promp = input("Digite uma pergunta: ")

# %% [markdown]
# # Estruturas de repetição

# %%
n = 1
while n <= 2:
   print("*")
   n = n + 1

# %% [markdown]
# # Lista

# %%
nome_alunos = ["João Silva", "Maria Souza", "Carlos Oliveira", "Ana Pereira", "Lucas Santos"]
print("------------ imprimir lista ------------ ")
print("")
print(nome_alunos)
print("")
print("------------ imprimir a quantidade de itens ------------ ")
print("")
print(len(nome_alunos))
print("")
print("------------ imprimir item na posicao 0 ao 2 ------------ ")
print("")
print(nome_alunos[0:2])
print("")
print("------------ imprimir da posicao 2 ate o final da lista ------------ ")
print("")
print(nome_alunos[1:])
print("")
print("------------ imprimir da posicao 2 ate o primeiro ------------ ")
print("")
print(nome_alunos[:2])
print("")
print("------------ adicionar item na lista ------------ ")
print("")
nome_alunos.append("Pedro Santos")
print(nome_alunos)
print("")
print("------------ adicionar multiplos itens ------------ ")
print("")
nome_alunos.extend(["a", "b", "c"])
print(nome_alunos)
print("")
print("------------ remover item ------------ ")
print("")
nome_alunos.remove("a")
nome_alunos.pop(len(nome_alunos)-1)
nome_alunos.pop()
print(nome_alunos)
print("")
print("------------ indice negativo ------------ ")
print("")
print(nome_alunos[-1])
print("")
print("------------ iterar pela lista e imprimir ------------ ")
print("")

n = 0
while n < len(nome_alunos):
  print(nome_alunos[n])
  n = n + 1
# Out:
# ------------ imprimir lista ------------
#
# ['João Silva', 'Maria Souza', 'Carlos Oliveira', 'Ana Pereira', 'Lucas Santos']
#
# ------------ imprimir a quantidade de itens ------------
#
# 5
#
# ------------ imprimir item na posicao 0 ao 2 ------------
#
# ['João Silva', 'Maria Souza']
#
# ------------ imprimir da posicao 2 ate o final da lista ------------
#
# ['Maria Souza', 'Carlos Oliveira', 'Ana Pereira', 'Lucas Santos']
#
# ------------ imprimir da posicao 2 ate o primeiro ------------
#
# ['João Silva', 'Maria Souza']
#
# ------------ adicionar item na lista ------------
#
# ['João Silva', 'Maria Souza', 'Carlos Oliveira', 'Ana Pereira', 'Lucas Santos', 'Pedro Santos']
#
# ------------ adicionar multiplos itens ------------
#
# ['João Silva', 'Maria Souza', 'Carlos Oliveira', 'Ana Pereira', 'Lucas Santos', 'Pedro Santos', 'a', 'b', 'c']
#
# ------------ remover item ------------
#
# ...

# %%
media_alunos = [7.5, 8.0, 6.8, 9.2, 7.9]
print(len(media_alunos))

n = 0
while n < len(media_alunos):
  if(media_alunos[n] >= 7):
    print(media_alunos[n])
  n = n + 1
# Out:
# 5
# 7.5
# 8.0
# 9.2
# 7.9

# %% [markdown]
# # Dicionários

# %%
print("------------ definindo um dicionario ------------ ")
print("")
dict_de_nomes_e_media = {"João Silva": 7.5, "Maria Souza": 8.0, "Carlos Oliveira": 6.8, "Ana Pereira": 9.2, "Lucas Santos": 7.9}
print(dict_de_nomes_e_media)
print("")

print("------------ acessar media atraves da chave ------------ ")
print("")
print(dict_de_nomes_e_media["João Silva"])
print(dict_de_nomes_e_media.get("João Silva"))
print("")

print("------------ remover elemento ------------ ")
print("")
dict_de_nomes_e_media.pop("João Silva")
print(dict_de_nomes_e_media)
print("")

print("------------ listar todas as chaves ------------ ")
print("")
print(dict_de_nomes_e_media.keys())
print("")

print("------------ listar todos os valores ------------ ")
print("")
print(dict_de_nomes_e_media.values())
print("")

print("------------ justando lista de nomes e medias ------------ ")
print("")
dict_desafio = [
    {"nome": "João Silva", "media": 7.5},
    {"nome": "Maria Souza", "media": 8.0},
    {"nome": "Carlos Oliveira", "media": 6.8},
]
print(dict_desafio)
print("")


print("------------ dicionario com nome e media ------------ ")
print("")
print(dict_desafio[0]["media"])
print("")

print("------------ iterando com for ------------ ")
print("")

for aluno in nome_alunos:
  print(aluno)

print("------------ iterando com for c/ range ------------ ")
print("")

for i in range(5):
  print(i)

print("------------ iterando com for c/ range ------------ ")
print("")

for i in range(5, 8):
  print(i)

print("------------ iterando com for c/ range ------------ ")
print("")

for i in range(2, 30, 2):
  print(i)

print("------------ iterando com for c/ range ------------ ")
print("")

dict_de_nomes_e_media = {"João Silva": 7.5, "Maria Souza": 8.0, "Carlos Oliveira": 6.8, "Ana Pereira": 9.2, "Lucas Santos": 7.9}
# Out:
# ------------ definindo um dicionario ------------
#
# {'João Silva': 7.5, 'Maria Souza': 8.0, 'Carlos Oliveira': 6.8, 'Ana Pereira': 9.2, 'Lucas Santos': 7.9}
#
# ------------ acessar media atraves da chave ------------
#
# 7.5
# 7.5
#
# ------------ remover elemento ------------
#
# {'Maria Souza': 8.0, 'Carlos Oliveira': 6.8, 'Ana Pereira': 9.2, 'Lucas Santos': 7.9}
#
# ------------ listar todas as chaves ------------
#
# dict_keys(['Maria Souza', 'Carlos Oliveira', 'Ana Pereira', 'Lucas Santos'])
#
# ------------ listar todos os valores ------------
#
# dict_values([8.0, 6.8, 9.2, 7.9])
#
# ------------ justando lista de nomes e medias ------------
#
# [{'nome': 'João Silva', 'media': 7.5}, {'nome': 'Maria Souza', 'media': 8.0}, {'nome': 'Carlos Oliveira', 'media': 6.8}]
#
# ------------ dicionario com nome e media ------------
#
# 7.5
#
# ------------ iterando com for ------------
#
# João Silva
# Maria Souza
# Carlos Oliveira
# Ana Pereira
# Lucas Santos
# Pedro Santos
# ...

# %% [markdown]
# # Funções

# %%
nome_1 = "   jOÃo    sIlVa   "
nome_2 = "mArIa     doS   sAnToS"
nome_3 = "   peDro    ALMEIDA"
nome_4 = "aNa    cLaRa   ferReIrA   "
nome_5 = "   luCaS    RoDrIgUeS   "
nome_6 = "CaMiLa    dE   oLiVeIrA"
nome_7 = "   rAfAeL   coStA"
nome_8 = "beAtRiZ     soUzA   "
nome_9 = "   feLiPe    lImA   "
nome_10 = "jÚlIa    baRBoSa    "



def fomatString(nome):
  maiusculo = nome.upper()
  removerEspaco = maiusculo.replace("  ", " ")
  removerEspaco2 = removerEspaco.strip()
  listaPalabras = removerEspaco2.split()
  format = " ".join(listaPalabras)
  return format

print(fomatString(nome_1))
print(fomatString(nome_2))
print(fomatString(nome_3))
# Out:
# JOÃO SILVA
# MARIA DOS SANTOS
# PEDRO ALMEIDA

# %%
import random

nome_11 = "Ana Julia"
salas_de_aulas = ["sala1", "sala2", "sala3"]

def aloca_alunos_em_salas(nome_do_aluno, lista_de_salas):
    sala_escolhida = random.choice(lista_de_salas)
    dict_aluno = {
        "nome": nome_do_aluno,
        "sala": sala_escolhida
    }
    return dict_aluno

print(aloca_alunos_em_salas(nome_11, salas_de_aulas)    )
# Out:
# {'nome': 'Ana Julia', 'sala': 'sala2'}

# %% [markdown]
# # Gerando arquivos

# %% [markdown]
# ## Gerando dados

# %%
import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get('GEMINI_API_KEY')
from google import genai
client = genai.Client()

testando_writer = [
    """Olá João,

Gostaria de agradecer pelo seu contato e interesse em nossos serviços.
Ficamos felizes em poder ajudar e estamos à disposição para esclarecer qualquer dúvida.

Atenciosamente,
Equipe de Suporte
""",

    """Bom dia Maria,

Estamos entrando em contato para informar que sua solicitação foi recebida com sucesso.
Nossa equipe já iniciou a análise e retornaremos em breve.

Cordialmente,
Departamento de Atendimento
""",

    """Olá Pedro,

Esperamos que você esteja bem.
Segue em anexo o documento solicitado para sua avaliação.

Atenciosamente,
Equipe Financeira
""",

    """Boa tarde Ana,

Gostaríamos de confirmar sua participação na reunião marcada para amanhã às 14h.
Caso tenha algum imprevisto, por favor nos avise.

Atenciosamente,
Equipe Comercial
""",

    """Olá Carlos,

Seu cadastro foi atualizado com sucesso em nosso sistema.
Agradecemos pela colaboração e confiança.

Cordialmente,
Equipe Administrativa
""",

    """Bom dia Fernanda,

Estamos enviando este e-mail para lembrar sobre o vencimento da sua mensalidade.
Qualquer dúvida, entre em contato conosco.

Atenciosamente,
Equipe Financeira
""",

    """Olá Lucas,

Recebemos seu currículo e agradecemos pelo interesse na vaga.
Em breve retornaremos com mais informações sobre o processo seletivo.

Cordialmente,
Recursos Humanos
""",

    """Boa tarde Juliana,

Seu pedido foi processado e já está em fase de envio.
Assim que houver atualização no rastreamento, avisaremos você.

Atenciosamente,
Equipe de Logística
""",

    """Olá Ricardo,

A reunião foi reagendada para sexta-feira às 10h.
Agradecemos pela compreensão.

Cordialmente,
Equipe de Projetos
""",

    """Bom dia Camila,

Gostaríamos de agradecer pela parceria e confiança em nosso trabalho.
Continuamos à disposição para futuras demandas.

Atenciosamente,
Equipe Executiva
"""
]

testando_append = ["append"]

def resumidor_email(lista_de_email):
   newList = [""]
   for numero, email in enumerate(lista_de_email):
      newList.append(email)
      # resposta = client.models.generate_content(model="gemini-2.5-flash", contents = f"""vou te mandar o corpo de um email. Quero que vc o resuma em apenas 1 linha com 3 palabras. Segue o email: {email}""")
      # print(f" existe {len(email)} caracteres no texto {email}")
      # print("-" * len(email))
   return newList

# %% [markdown]
# ## Escrever
# usando a funcao abaixo iremos gerar um arquivo. Na assinatura do metodo passamos o "w" no segundo parametro, isso significa que o python ira criar um arquivo novo caso ele nao exista. Porem se existir ele ira deletar todos os dados dentro dele e adicionar novamente
#
# Passando o "a" o python ira incrementar novos dados no final do arquivo
#
# ```
# with open("meu_arquivo.txt", "w" ou "a", encoding="utf8") as arquivo
# ```
#
# ```
# with open("arquivo_com_dados.txt", "a", encoding="utf8") as arquivo:
#   for email in corpos_email:
#     arquivo.write(email)
#     arquivo.write("\n")
# ```

# %%
with open("arquivo_com_dados.txt", "a", encoding="utf8") as arquivo:
  for email in testando_append:
    arquivo.write(email)
    arquivo.write("\n")

# %% [markdown]
# ## Ler arquivo
#
# Para ler iremos substituir o segundo parametro pelo "r"
#
#
# ```
# with open("meu_arquivo.txt", "r", encoding="utf8") as arquivo
# ```
#
# ```
# with open("arquivo_com_dados.txt", "a", encoding="utf8") as arquivo:
#   for email in corpos_email:
#     arquivo.write(email)

# %%
nova_lista_de_leitura = [""]
with open("arquivo_com_dados.txt", "r", encoding="utf8") as arquivo:
  for email in arquivo:
    nova_lista_de_leitura.append(email)
print(nova_lista_de_leitura)
# Out:
# ['', 'Olá João,\n', '\n', 'Gostaria de agradecer pelo seu contato e interesse em nossos serviços.\n', 'Ficamos felizes em poder ajudar e estamos à disposição para esclarecer qualquer dúvida.\n', '\n', 'Atenciosamente,\n', 'Equipe de Suporte\n', '\n', 'Bom dia Maria,\n', '\n', 'Estamos entrando em contato para informar que sua solicitação foi recebida com sucesso.\n', 'Nossa equipe já iniciou a análise e retornaremos em breve.\n', '\n', 'Cordialmente,\n', 'Departamento de Atendimento\n', '\n', 'Olá Pedro,\n', '\n', 'Esperamos que você esteja bem.\n', 'Segue em anexo o documento solicitado para sua avaliação.\n', '\n', 'Atenciosamente,\n', 'Equipe Financeira\n', '\n', 'Boa tarde Ana,\n', '\n', 'Gostaríamos de confirmar sua participação na reunião marcada para amanhã às 14h.\n', 'Caso tenha algum imprevisto, por favor nos avise.\n', '\n', 'Atenciosamente,\n', 'Equipe Comercial\n', '\n', 'Olá Carlos,\n', '\n', 'Seu cadastro foi atualizado com sucesso em nosso sistema.\n', 'Agradecemos pe
# ...

# %% [markdown]
# # Panda para data science

# %% [markdown]
# ## O que e como funciona

# %%
import pandas as pd
df = pd.read_csv("/content/meu_csv.csv")
print("")
print("=================imprimindo dataframe =================")
print(df)
print("")
print("=================imprimindo com head =================")
print(df.head())
print("")
print("=================imprimindo com tail =================")
print(df.tail())
print("")
# Out:
# =================imprimindo dataframe =================
#                  Nome  Média
# 0       Maria Barbosa    9.3
# 1     Rafael Ferreira    9.6
# 2         Carla Gomes    9.7
# 3        Ursula Souza    5.5
# 4          João Lopes    7.6
# 5       Fábio Pereira    4.5
# 6        Ursula Silva    7.3
# 7        Olívia Souza    9.7
# 8         Sofia Lopes    5.1
# 9       Carla Ribeiro    4.0
# 10      João Carvalho    4.6
# 11     Carla Teixeira    4.9
# 12     Wagner Ribeiro    8.1
# 13       Xavier Rocha    4.2
# 14      Natan Ribeiro    7.2
# 15       Ursula Gomes    4.1
# 16   Giovanna Almeida    6.4
# 17       Natan Santos    6.3
# 18     Vitor Teixeira    4.1
# 19         Fábio Lima    5.1
# 20         Zeca Costa    6.9
# 21       Elena Vieira    9.5
# 22        Lucas Lopes    4.0
# 23  Henrique Teixeira    5.9
# 24        Fábio Costa    6.2
# 25     Giovanna Souza    4.9
# 26     Ursula Ribeiro    8.1
# 27       Vitor Mendes    7.8
# 28       Wagner Rocha    7.2
# ...

# %%
import pandas as pd

data = {
    'nome do produto': [],
    'categoria do produto': [],
    'preco': [],
    'avalicao produto': []
}
df_produtos = pd.DataFrame(data)

print("================= DataFrame de Produtos =================")
print(df_produtos)
print("\n================= Informações do DataFrame =================")
print(df_produtos.info())

# %% [markdown]
# ### Gerando dados para o DataFrame de Produtos
#
# Vou criar 50 linhas de dados simulados, incluindo uma coluna para a quantidade vendida, para que possamos calcular o total de itens e produtos vendidos.

# %%
import numpy as np

nomes_produtos = [
    'Laptop Gamer', 'Smartphone Ultra', 'Smartwatch Esportivo', 'Fone Bluetooth',
    'Teclado Mecânico', 'Mouse Sem Fio', 'Monitor Curvo', 'Webcam Full HD',
    'Impressora Multifuncional', 'Roteador Wi-Fi 6', 'Console de Jogos', 'Tablet Pro',
    'Caixa de Som Portátil', 'Controle Remoto Universal', 'Câmera Digital',
    'Microfone Condensador', 'Ring Light', 'HD Externo 1TB', 'SSD Portátil 500GB',
    'Pendrive USB 3.0', 'Carregador Sem Fio', 'Power Bank 20000mAh', 'Filtro de Linha',
    'Projetor Portátil', 'Óculos VR', 'Drone com Câmera', 'Kit Casa Inteligente',
    'Lâmpada Inteligente', 'Tomada Inteligente', 'Fechadura Eletrônica', 'Aspirador Robô',
    'Cafeteira Expresso', 'Air Fryer', 'Liquidificador Alta Potência', 'Robô de Cozinha',
    'Panela Elétrica', 'Batedeira Planetária', 'Forno Elétrico', 'Geladeira Smart',
    'Máquina de Lavar', 'Secadora de Roupas', 'Ferro de Passar a Vapor', 'Patinete Elétrico',
    'Bicicleta Elétrica', 'Skate Elétrico', 'Balança Inteligente', 'Massageador Elétrico',
    'Depilador Elétrico', 'Escova Elétrica', 'Máquina de Cortar Cabelo'
]

categorias_produtos = [
    'Eletrônicos', 'Periféricos', 'Games', 'Casa Inteligente', 'Eletrodomésticos', 'Mobilidade'
]

data_simulada = {
    'nome do produto': np.random.choice(nomes_produtos, 50),
    'categoria do produto': np.random.choice(categorias_produtos, 50),
    'preco': np.round(np.random.uniform(50, 5000, 50), 2),
    'avalicao produto': np.random.randint(1, 6, 50), # Avaliação de 1 a 5
    'quantidade_vendida': np.random.randint(1, 20, 50) # Quantidade de itens vendidos por 'venda'
}

df_produtos_vendas = pd.DataFrame(data_simulada)

#print("================= DataFrame de Produtos e Vendas =================")
#display(df_produtos_vendas.head())

#print("================= DataFrame completo =================")
 #display(df_produtos_vendas)

#print("================= DataFrame retornar dados de uma coluna especifica == categoria do produto =================")
#display(df_produtos_vendas["categoria do produto"])
#display(df_produtos_vendas["categoria do produto"].unique())
#display(set(df_produtos_vendas["categoria do produto"].unique()))

#print("============   filtrando dados  ============")
#display(df_produtos_vendas[df_produtos_vendas["categoria do produto"] == "Eletrônicos"])

# print("============   filtrando por valor  ============")
# display(df_produtos_vendas[df_produtos_vendas["preco"] <= 700])

# print("============   quantidade linhas e colunas  ============")
# display(df_produtos_vendas.shape)

# print("============   pegar dados pelo indice  ============")
# display(df_produtos_vendas.iloc[2])

print("============   pegar dados pelo indice do ponto indicie 1 ao 5 ============")
display(df_produtos_vendas.iloc[0:5])
# Out:
# ============   pegar dados pelo indice do ponto indicie 1 ao 5 ============
#              nome do produto categoria do produto    preco  avalicao produto  \
# 0           Roteador Wi-Fi 6                Games  3737.86                 4
# 1            Escova Elétrica          Eletrônicos  2294.50                 3
# 2          Projetor Portátil                Games  3342.66                 1
# 3  Controle Remoto Universal           Mobilidade  4864.75                 5
# 4  Impressora Multifuncional          Eletrônicos   926.66                 4
#
#    quantidade_vendida
# 0                   1
# 1                   4
# 2                   1
# 3                  14
# 4                   1

# %% [markdown]
# ### Análise de Vendas
#
# Agora vamos calcular quantos itens e produtos únicos foram vendidos com base no DataFrame gerado.

# %%
total_itens_vendidos = df_produtos_vendas['quantidade_vendida'].sum()
numero_produtos_distintos_vendidos = df_produtos_vendas['nome do produto'].nunique()

print(f"Total de itens vendidos (soma das quantidades): {total_itens_vendidos}")
print(f"Número de produtos distintos vendidos: {numero_produtos_distintos_vendidos}")
# Out:
# Total de itens vendidos (soma das quantidades): 500
# Número de produtos distintos vendidos: 37

# %% [markdown]
# ## Analise de sentimento
